# %% [markdown]
# <a href="https://colab.research.google.com/github/sul0211/SyamsulBuchoriPane_JS1/blob/main/SIG_A5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import geopandas as gpg
from geopandas import datasets, read_file, geodataframe
import matplotlib.pyplot as plt

# %%
zipfile = "lsm.zip"
kota = gpd.read_file(zipfile)

# %%
kota.head()
# Out:
#   KDPPUM       NAMOBJ  ... SHAPE_Area                                           geometry
# 0   None   BANDASAKTI  ...   0.000888  POLYGON Z ((97.13359 5.17511 0.00000, 97.13327...
# 1   None  BLANGMANGAT  ...   0.003945  POLYGON Z ((97.09851 5.16797 0.00000, 97.09845...
# 2   None    MUARA DUA  ...   0.002193  POLYGON Z ((97.13359 5.17511 0.00000, 97.13349...
# 3   None   MUARA SATU  ...   0.004098  POLYGON Z ((97.11641 5.21582 0.00000, 97.11612...
#
# [4 rows x 28 columns]

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
kota.plot()
# Out:
# <Axes: >

# %%
kota.plot(column='NAMOBJ')
# Out:
# <Axes: >

# %%
kota.plot(column='NAMOBJ', legend=True)
# Out:
# <Axes: >

# %%
kota.plot(column='NAMOBJ', legend=True, legend_kwds={"loc": "center left", "bbox_to_anchor": (1, 0.5)},)
# Out:
# <Axes: >
